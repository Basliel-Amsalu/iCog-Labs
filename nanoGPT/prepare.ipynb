# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

np.random.seed(42)

# %%
data = pd.read_csv('Amharic News Dataset.csv')

data = shuffle(data)
data.head()
# Out:
#                                                 headline    category  \
# 44810  በመዲናዋ የጋራ መኖሪያ ቤቶችን ግንባታ ለማጠናቀቅና ለማስጀመር የ20 ቢሊ...        ፖለቲካ
# 18329  አሸንዳ፣ ሻደይ፣ አሸንድዬ፣ ሶለል፣ ማሪያና ዓይኒ ዋሪ በዓል በዩኔስኮ አ...  ሀገር አቀፍ ዜና
# 17644  ግምታዊ ዋጋቸው ከ31 ነጥብ 6 ሚሊየን ብር በላይ የሆኑ የኮንትሮባንድ ዕ...  ሀገር አቀፍ ዜና
# 32773       ​ባምላክ ተሰማ የዓለም ዋንጫ ለመምራት እጩ ከሆኑ ዳኞች ውስጥ ተካተተ        ስፖርት
# 4139              “መንገድ ለሰው” መርሐ ግብር በየሳምንቱ እንደሚካሄድ ተገለፀ  ሀገር አቀፍ ዜና
#
#                      date    views  \
# 44810  September 14, 2017  Unknown
# 18329         Jan 8, 2020      387
# 17644         Mar 4, 2020      634
# 32773   November 19, 2017  Unknown
# 4139       August 7, 2019       32
#
#                                                  article  \
# 44810  በአዲስ አበባ የተጀመሩ የጋራ መኖሪያ ቤቶችን ግንባታ ለማጠናቀቅና አዳዲስ...
# 18329  አዲስ አበባ፣ ታህሳስ 29፣ 2012 (ኤፍ.ቢ.ሲ) የአሸንዳ፣ ሻደይ፣ አሸ...
# 17644  አዲስ አበባ ፣ የካቲት 25 ፣ 2012 (ኤፍ ቢ ሲ) ባለፉት አምስት ቀና...
# 32773  ሩሲያ በ2018 ለምታስተናግደው የዓለም ዋንጫ ፊፋ ጨዋታዎችን ሊመሩ የሚች...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51483 entries, 44810 to 15795
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   headline  51470 non-null  object
#  1   category  51482 non-null  object
#  2   date      51483 non-null  object
#  3   views     51483 non-null  object
#  4   article   51483 non-null  object
#  5   link      51483 non-null  object
# dtypes: object(6)
# memory usage: 2.7+ MB

# %%
data = data.dropna(subset=['article'])

# %%
data['link'].value_counts()
# Out:
# link
# https://amharic.voanews.com//a/amb-tibor-nagy-in-addis-ababa-on-sudan-06-14-19/4960197.html                                                                                                                                                                                                                                                 3
# https://amharic.voanews.com//a/covid-africa/5535902.html                                                                                                                                                                                                                                                                                    3
# ...

# %%
data.category.unique()
# Out:
# array(['ፖለቲካ', 'ሀገር አቀፍ ዜና', 'ስፖርት', 'ዓለም አቀፍ ዜና', 'ቢዝነስ', 'መዝናኛ', nan],
#       dtype=object)

# %%
data['word_len'] = data['article'].str.split().str.len()
data.head()
# Out:
#                                                 headline    category  \
# 44810  በመዲናዋ የጋራ መኖሪያ ቤቶችን ግንባታ ለማጠናቀቅና ለማስጀመር የ20 ቢሊ...        ፖለቲካ
# 18329  አሸንዳ፣ ሻደይ፣ አሸንድዬ፣ ሶለል፣ ማሪያና ዓይኒ ዋሪ በዓል በዩኔስኮ አ...  ሀገር አቀፍ ዜና
# 17644  ግምታዊ ዋጋቸው ከ31 ነጥብ 6 ሚሊየን ብር በላይ የሆኑ የኮንትሮባንድ ዕ...  ሀገር አቀፍ ዜና
# 32773       ​ባምላክ ተሰማ የዓለም ዋንጫ ለመምራት እጩ ከሆኑ ዳኞች ውስጥ ተካተተ        ስፖርት
# 4139              “መንገድ ለሰው” መርሐ ግብር በየሳምንቱ እንደሚካሄድ ተገለፀ  ሀገር አቀፍ ዜና
#
#                      date    views  \
# 44810  September 14, 2017  Unknown
# 18329         Jan 8, 2020      387
# 17644         Mar 4, 2020      634
# 32773   November 19, 2017  Unknown
# 4139       August 7, 2019       32
#
#                                                  article  \
# 44810  በአዲስ አበባ የተጀመሩ የጋራ መኖሪያ ቤቶችን ግንባታ ለማጠናቀቅና አዳዲስ...
# 18329  አዲስ አበባ፣ ታህሳስ 29፣ 2012 (ኤፍ.ቢ.ሲ) የአሸንዳ፣ ሻደይ፣ አሸ...
# 17644  አዲስ አበባ ፣ የካቲት 25 ፣ 2012 (ኤፍ ቢ ሲ) ባለፉት አምስት ቀና...
# 32773  ሩሲያ በ2018 ለምታስተናግደው የዓለም ዋንጫ ፊፋ ጨዋታዎችን ሊመሩ የሚች...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51483 entries, 44810 to 15795
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   headline  51470 non-null  object
#  1   category  51482 non-null  object
#  2   date      51483 non-null  object
#  3   views     51483 non-null  object
#  4   article   51483 non-null  object
#  5   link      51483 non-null  object
#  6   word_len  51483 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 3.1+ MB

# %%
data.word_len.mean()
# Out:
# 248.9586853912942

# %%
import re
#method to normalize character level missmatch such as ጸሀይ and ፀሐይ
def normalize_char_level_missmatch(input_token):
    rep1=re.sub('[ሃኅኃሐሓኻ]','ሀ',input_token)
    rep2=re.sub('[ሑኁዅ]','ሁ',rep1)
    rep3=re.sub('[ኂሒኺ]','ሂ',rep2)
    rep4=re.sub('[ኌሔዄ]','ሄ',rep3)
    rep5=re.sub('[ሕኅ]','ህ',rep4)
    rep6=re.sub('[ኆሖኾ]','ሆ',rep5)
    rep7=re.sub('[ሠ]','ሰ',rep6)
    rep8=re.sub('[ሡ]','ሱ',rep7)
    rep9=re.sub('[ሢ]','ሲ',rep8)
    rep10=re.sub('[ሣ]','ሳ',rep9)
    rep11=re.sub('[ሤ]','ሴ',rep10)
    rep12=re.sub('[ሥ]','ስ',rep11)
    rep13=re.sub('[ሦ]','ሶ',rep12)
    rep14=re.sub('[ዓኣዐ]','አ',rep13)
    rep15=re.sub('[ዑ]','ኡ',rep14)
    rep16=re.sub('[ዒ]','ኢ',rep15)
    rep17=re.sub('[ዔ]','ኤ',rep16)
    rep18=re.sub('[ዕ]','እ',rep17)
    rep19=re.sub('[ዖ]','ኦ',rep18)
    rep20=re.sub('[ጸ]','ፀ',rep19)
    rep21=re.sub('[ጹ]','ፁ',rep20)
    rep22=re.sub('[ጺ]','ፂ',rep21)
    rep23=re.sub('[ጻ]','ፃ',rep22)
    rep24=re.sub('[ጼ]','ፄ',rep23)
    rep25=re.sub('[ጽ]','ፅ',rep24)
    rep26=re.sub('[ጾ]','ፆ',rep25)
    #Normalizing words with Labialized Amharic characters such as በልቱዋል or  በልቱአል to  በልቷል  
    rep27=re.sub('(ሉ[ዋአ])','ሏ',rep26)
    rep28=re.sub('(ሙ[ዋአ])','ሟ',rep27)
    rep29=re.sub('(ቱ[ዋአ])','ቷ',rep28)
    rep30=re.sub('(ሩ[ዋአ])','ሯ',rep29)
    rep31=re.sub('(ሱ[ዋአ])','ሷ',rep30)
    rep32=re.sub('(ሹ[ዋአ])','ሿ',rep31)
    rep33=re.sub('(ቁ[ዋአ])','ቋ',rep32)
    rep34=re.sub('(ቡ[ዋአ])','ቧ',rep33)
    rep35=re.sub('(ቹ[ዋአ])','ቿ',rep34)
    rep36=re.sub('(ሁ[ዋአ])','ኋ',rep35)
    rep37=re.sub('(ኑ[ዋአ])','ኗ',rep36)
    rep38=re.sub('(ኙ[ዋአ])','ኟ',rep37)
    rep39=re.sub('(ኩ[ዋአ])','ኳ',rep38)
    rep40=re.sub('(ዙ[ዋአ])','ዟ',rep39)
    rep41=re.sub('(ጉ[ዋአ])','ጓ',rep40)
    rep42=re.sub('(ደ[ዋአ])','ዷ',rep41)
    rep43=re.sub('(ጡ[ዋአ])','ጧ',rep42)
    rep44=re.sub('(ጩ[ዋአ])','ጯ',rep43)
    rep45=re.sub('(ጹ[ዋአ])','ጿ',rep44)
    rep46=re.sub('(ፉ[ዋአ])','ፏ',rep45)
    rep47=re.sub('[ቊ]','ቁ',rep46) #ቁ can be written as ቊ
    rep48=re.sub('[ኵ]','ኩ',rep47) #ኩ can be also written as ኵ  
    return rep48

# %%
data['article'] = data['article'].str.replace('[^\w\s]','')

# %%
data['article'] = data['article'].apply(lambda x: normalize_char_level_missmatch(x))

# %%
n_data = data[['article','headline', 'category']]
n_data_filtered = n_data[n_data['category'] == 'ቢዝነስ']
n_data_filtered.head()

# n_data_filtered['content'] = n_data_filtered['content'].apply(remove_english)
# 'ፖለቲካ', 'ሀገር አቀፍ ዜና', 'ስፖርት', 'ዓለም አቀፍ ዜና', 'ቢዝነስ', 'መዝናኛ'
# Out:
#                                                  article  \
# 6974   ይህን ጉዳይ የድሮ ዘመን አስተሳሰብና አሰራር እንጂ በአሁኑ ዘመነኛ ጊዜ ...
# 24774  የአዲስ አበባ ከተማ አስተዳደር በአምስት ክፍላተ ከተሞች 124 ቦታዎችን ...
# 6779     ባለፈው ሳምንት የመንግስት ኮሙኒኬሽን ጉዳዮች ፅ/ቤት ከተለያዩ ሚዲያዎ...
# 25044  የአባይ ባንክ አክሲዮን ማሀበር ኢንፎርሜሽን ቴክኖሎጂ (አይቲ) ክፍል፣ የ...
# 45320  ጅቡቲ በቅርቡ ገንብታ  ወደ ስራ ካስገባቻቸው ሁለተኛው የሆነው  ወደብ የ...
#
#                                                 headline category
# 6974                          የዓለም እውነታ የተገላቢጦሽ እየሆነነው!      ቢዝነስ
# 24774                      የአዲስ አበባ ከተማ 23ኛው የሊዝ ጨረታ አወጣ     ቢዝነስ
# 6779                         የኢንዱስትሪው ዘርፍ የተጋፈጣቸው ፈተናዎች      ቢዝነስ
# 25044   የቴክኖሎጂ መክፈያ መሣሪያዎችን ተጠቅመው 440 ሺሕ ብር መውሰዳቸው ተጠቁሟል     ቢዝነስ
# 45320  ጅቡቲ  ለኢትዮጵያ የፖታሽ የወጪ ንግድ  የሚውል አዲስ ወደብ ለአገልግሎት...     ቢዝነስ

# %%
import re

def remove_english(text):
    """Remove English letters from text."""
    return re.sub(r'[A-Za-z]+', '', text)

with open('raw.txt', 'w', encoding='utf-8') as file:
    for index, row in n_data_filtered.iterrows():
        no_english_headline =  remove_english(row['headline'])
        no_english_article = remove_english(row['article'])
        file.write(f"{no_english_headline}\n{no_english_article}\n\n")

# %%
try:
    with open('raw.txt', 'r', encoding='utf-8') as f:
        data = f.read(2000000) 

    with open('processed_data.txt', 'w', encoding='utf-8') as file:
        file.write(data)
except Exception as e:
    print(f"An error occurred: {e}")

# %%
with open('processed_data.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
print("length of dataset in characters: ", len(text))
# Out:
# length of dataset in characters:  2000000

# %%
print(text[:10000])
# Out:
# የዓለም እውነታ የተገላቢጦሽ እየሆነነው!
# ...

# %%
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#  !"#%&'()*+,-./0123456789:;<=>?[]|~ §«´·ÃÝ÷ùሀሁሂሃሄህሆለሉሊላሌልሎሏሐሒሓሔሕመሙሚማሜምሞሟሠሣሥሦረሩሪራሬርሮሯሰሱሲሳሴስሶሷሸሹሺሻሼሽሾሿቀቁቂቃቄቅቆቋቐበቡቢባቤብቦቧቨቩቪቫቬቭቮቯተቱቲታቴትቶቷቸቹቺቻቼችቾቿኀኃኅኋነኑኒናኔንኖኗኘኙኚኛኜኝኞኟአኡኢኤእኦኧከኩኪካኬክኮኰኳኵኸኹኼኽወዉዊዋዌውዎዐዑዒዓዔዕዘዙዚዛዜዝዞዟዠዡዢዣዤዥዦየዩያዬይዮደዱዲዳዴድዶዷዽጀጁጂጃጄጅጆጇገጉጊጋጌግጎጐጓጠጡጢጣጤጥጦጧጨጩጪጫጬጭጮጯጰጲጳጴጵጸጹጻጽጿፀፁፂፃፄፅፆፈፉፊፋፌፍፎፏፐፑፒፓፔፕፖ፡።፣፤፥፦​–‘’‚“”•…‹›
# 308

# %%
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] 
decode = lambda l: ''.join([itos[i] for i in l]) 

print(encode("ኢትዮጵያውያን ከቤሩት ተመለሱ"))
print(decode(encode("ኢትዮጵያውያን ከቤሩት ተመለሱ")))
# Out:
# [164, 131, 216, 263, 213, 188, 213, 151, 1, 169, 114, 78, 131, 1, 126, 65, 52, 86]
# ኢትዮጵያውያን ከቤሩት ተመለሱ

# %%
import torch 
data = torch.tensor(encode(text), dtype=torch.long)
print(data.shape, data.dtype)
print(data[:1000])
